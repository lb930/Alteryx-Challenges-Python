# %% [markdown]
# # Challenge #224: Mushroom for Improvement
#
# This week's challenge focuses on a dataset describing mushrooms which has been encoded. In the 23 columns describing each mushroom observed, the values are represented by a single character. Use the Attribute Info table to replace the coded information with the values they represent.
#
# Original challenge: https://community.alteryx.com/t5/Weekly-Challenge/Challenge-224-Mushroom-for-Improvement/td-p/602542

# %%
import pandas as pd
pd.options.display.max_colwidth = 100

# %% [markdown]
# ### Import the datasets

# %%
df_mushrooms = pd.read_csv('./challenge_224_input.csv')

# %%
df_mushrooms.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df_attributes = pd.read_csv('./challenge_224_input2.csv')
df_attributes.head(5)
# Out:
#                                                                                            Field1
# 0                                         Attribute Information: (classes: edible=e, poisonous=p)
# 1                                 cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2                                               cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3      cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# 4                                                                         bruises: bruises=t,no=f

# %% [markdown]
# ### Clean df_attributes dataset
# First, we want to make sure that the headers between the two datasets match.

# %%
def clean_strings(text, replacement):
    df_attributes['Field1'] = df_attributes['Field1'].replace(to_replace=text, value=replacement, regex = True)

# %%
clean_strings('Attribute Information: \(', '')
clean_strings('\)', '')
clean_strings('classes', 'class')

# %% [markdown]
# Here, we split the headers from the values which we can use to decode the abbreviations in the mushroom dataset.

# %%
df_attributes[['Header', 'Translations']] = df_attributes['Field1'].str.split(': ', expand = True)
df_attributes.head()
# Out:
#                                                                                            Field1  \
# 0                                                                    class: edible=e, poisonous=p
# 1                                 cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2                                               cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
# 3      cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# 4                                                                         bruises: bruises=t,no=f
#
#             Header  \
# 0            class
# 1        cap-shape
# 2      cap-surface
# 3        cap-color
# 4          bruises
#
#                                                                       Translations
# 0                                                            edible=e, poisonous=p
# 1                             bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
# 2                                             fibrous=f,grooves=g,scaly=y,smooth=s
# 3  brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
# 4                                                                   bruises=t,no=f

# %% [markdown]
# We split the dataset into rows so that we get one attribute per row.

# %%
del df_attributes['Field1']
df_attributes = df_attributes.set_index(['Header']).apply(lambda x: x.str.split(',').explode()).reset_index() 
df_attributes.head()
# Out:
#           Header  Translations
# 0          class      edible=e
# 1          class   poisonous=p
# 2      cap-shape        bell=b
# 3      cap-shape     conical=c
# 4      cap-shape      convex=x

# %% [markdown]
# We use = as delimiter to separate abbreviation and decoding

# %%
df_attributes[['Decoded', 'Abbreviation']] = df_attributes['Translations'].str.split('=', expand = True)
df_attributes.head()
# Out:
#           Header  Translations     Decoded Abbreviation
# 0          class      edible=e      edible            e
# 1          class   poisonous=p   poisonous            p
# 2      cap-shape        bell=b        bell            b
# 3      cap-shape     conical=c     conical            c
# 4      cap-shape      convex=x      convex            x

# %% [markdown]
# Splitting into columns has produced white space that we need to remove.

# %%
df_attributes['Header'] = df_attributes['Header'].str.strip()
df_attributes['Abbreviation'] = df_attributes['Abbreviation'].str.strip()
df_attributes.head()
# Out:
#       Header  Translations     Decoded Abbreviation
# 0      class      edible=e      edible            e
# 1      class   poisonous=p   poisonous            p
# 2  cap-shape        bell=b        bell            b
# 3  cap-shape     conical=c     conical            c
# 4  cap-shape      convex=x      convex            x

# %% [markdown]
# ### Reshaping the mushroom dataset
#
# We want to pivot the mushroom dataset so we can join it on the attributes dataset. In order to bring it back into its original shape later on, we use the index to create a record ID.

# %%
df_mushrooms.reset_index(level=0, inplace=True)
df_mushrooms.head()
# Out:
#    index class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      0     p         x           s         n       t    p               f
# 1      1     e         x           s         y       t    a               f
# 2      2     e         b           s         w       t    l               f
# 3      3     p         x           y         w       t    p               f
# 4      4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size  ... stalk-surface-below-ring stalk-color-above-ring  \
# 0            c         n  ...                        s                      w
# 1            c         b  ...                        s                      w
# 2            c         b  ...                        s                      w
# 3            c         n  ...                        s                      w
# 4            w         b  ...                        s                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
#
#   spore-print-color population habitat
# 0                 k          s       u
# 1                 n          n       g
# 2                 n          n       m
# 3                 k          s       u
# 4                 n          a       g
#
# [5 rows x 24 columns]

# %% [markdown]
# The following steps pivots the dataset.

# %%
df_mushrooms = pd.melt(df_mushrooms, id_vars='index')
df_mushrooms.sort_values(by='index', inplace = True)
df_mushrooms.head(5)
# Out:
#         index           variable value
# 0           0              class     p
# 146232      0        ring-number     o
# 40620       0               odor     p
# 24372       0          cap-color     n
# 162480      0  spore-print-color     k

# %% [markdown]
# We can now join df_mushroom and df_attributes using both the header/variable and abbreviation/value as join conditions to make sure each abbreviations is associated with the correct header. A single abbreviation/header join condition would likely caus duplicates.

# %%
df_join = df_mushrooms.merge(df_attributes, how="inner", left_on=['variable', 'value'], right_on=['Header', 'Abbreviation'])
df_join.sort_values(by='index', inplace = True)
df_join
# Out:
#         index                variable value                  Header  \
# 0           0                   class     p                   class
# 76874       0  stalk-color-above-ring     w  stalk-color-above-ring
# 76466       0              gill-color     k              gill-color
# 75218       0              population     s              population
# 72706       0               gill-size     n               gill-size
# ...       ...                     ...   ...                     ...
# 186241   8123         gill-attachment     a         gill-attachment
# 186535   8123       spore-print-color     o       spore-print-color
# 50369    8123               ring-type     p               ring-type
# 130313   8123                 bruises     f                 bruises
# 13943    8123               cap-color     n               cap-color
#
#         Translations     Decoded Abbreviation
# 0        poisonous=p   poisonous            p
# 76874        white=w       white            w
# 76466        black=k       black            k
# 75218    scattered=s   scattered            s
# 72706       narrow=n      narrow            n
# ...              ...         ...          ...
# 186241    attached=a    attached            a
# 186535      orange=o      orange            o
# 50369      pendant=p     pendant            p
# 130313          no=f          no            f
# 13943        brown=n       brown            n
#
# [186852 rows x 7 columns]

# %% [markdown]
# We only keep 3 columns to unpivot the table

# %%
df_join = df_join[['index', 'variable', 'Decoded']]
df_join.head()
# Out:
#        index                variable     Decoded
# 0          0                   class   poisonous
# 76874      0  stalk-color-above-ring       white
# 76466      0              gill-color       black
# 75218      0              population   scattered
# 72706      0               gill-size      narrow

# %%
df_join = df_join.pivot(index = 'index', columns='variable', values='Decoded')
df_join
# Out:
# variable  bruises cap-color cap-shape cap-surface       class gill-attachment  \
# index
# 0         bruises     brown    convex      smooth   poisonous            free
# 1         bruises    yellow    convex      smooth      edible            free
# 2         bruises     white      bell      smooth      edible            free
# 3         bruises     white    convex       scaly   poisonous            free
# 4              no      gray    convex      smooth      edible            free
# ...           ...       ...       ...         ...         ...             ...
# 8119           no     brown   knobbed      smooth      edible        attached
# 8120           no     brown    convex      smooth      edible        attached
# 8121           no     brown      flat      smooth      edible        attached
# 8122           no     brown   knobbed       scaly   poisonous            free
# 8123           no     brown    convex      smooth      edible        attached
#
# variable gill-color gill-size gill-spacing  habitat  ...   ring-type  \
# index                                                ...
# 0             black    narrow        close    urban  ...     pendant
# 1             black     broad        close  grasses  ...     pendant
# 2             brown     broad        close  meadows  ...     pendant
# 3             brown    narrow        close    urban  ...     pendant
# 4             black     broad      crowded  grasses  ...  evanescent
# ...             ...       ...          ...      ...  ...         ...
# 8119         yellow     broad        close   leaves  ...     pendant
# 8120         yellow     broad        close   leaves  ...     pendant
# 8121          brown     broad        close   leaves  ...     pendant
# 8122           buff    narrow        close   leaves  ...  evanescent
# 8123         yellow     broad        close   leaves  ...     pendant
#
# variable spore-print-color stalk-color-above-ring stalk-color-below-ring  \
# index
# 0                    black                  white                  white
# 1                    brown                  white                  white
# 2                    brown                  white                  white
# 3                    black                  white                  white
# 4                    brown                  white                  white
# ...                    ...                    ...                    ...
# 8119                  buff                 orange                 orange
# 8120                  buff                 orange                 orange
# 8121                  buff                 orange                 orange
# 8122                 white                  white                  white
# 8123                orange                 orange                 orange
#
# variable stalk-root stalk-shape stalk-surface-above-ring  \
# index
# 0             equal   enlarging                   smooth
# 1              club   enlarging                   smooth
# 2              club   enlarging                   smooth
# 3             equal   enlarging                   smooth
# 4             equal    tapering                   smooth
# ...             ...         ...                      ...
# 8119        missing   enlarging                   smooth
# 8120        missing   enlarging                   smooth
# 8121        missing   enlarging                   smooth
# 8122        missing    tapering                   smooth
# 8123        missing   enlarging                   smooth
#
# variable stalk-surface-below-ring veil-color veil-type
# index
# 0                          smooth      white   partial
# 1                          smooth      white   partial
# 2                          smooth      white   partial
# 3                          smooth      white   partial
# 4                          smooth      white   partial
# ...                           ...        ...       ...
# 8119                       smooth     orange   partial
# 8120                       smooth      brown   partial
# 8121                       smooth     orange   partial
# 8122                        silky      white   partial
# 8123                       smooth     orange   partial
#
# [8124 rows x 23 columns]
